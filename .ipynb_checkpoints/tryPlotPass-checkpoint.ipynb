# %%
import os
import warnings
import pandas as pd
from socceraction.data.statsbomb import StatsBombLoader
import socceraction.spadl as spadl
pd.set_option('display.max_columns', None)
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.filterwarnings(action="ignore", message="credentials were not supplied. open data access only")

# %%
SBL = StatsBombLoader()

# %%
df_events = SBL.events(game_id=7548)

# %%
df_players = SBL.players(game_id=7548)

# %%
df_players
# Out:
#     game_id  team_id  player_id                          player_name  \
# 0      7548      781       3054                   Fernando Luiz Rosa
# 1      7548      781       3202            Gabriel Fernando de Jesus
# 2      7548      781       3295             Thiago Emiliano da Silva
# 3      7548      781       3472              Willian Borges da Silva
# 4      7548      781       3501            Philippe Coutinho Correia
# 5      7548      781       3535  Roberto Firmino Barbosa de Oliveira
# 6      7548      781       4320        Neymar da Silva Santos Junior
# 7      7548      781       5539             Carlos Henrique Casimiro
# 8      7548      781       5542     José Paulo Bezzera Maciel Júnior
# 9      7548      781       5547                Alisson Ramsés Becker
# 10     7548      781       5551          João Miranda de Souza Filho
# 11     7548      781       5552       Marcelo Vieira da Silva Júnior
# 12     7548      781       5837               Douglas Costa de Souza
# 13     7548      781       5838                Fágner Conserva Lemos
# 14     7548      795       5582                    Celso Borges Mora
# 15     7548      795       5584            Giancarlo González Castro
# 16     7548      795       5586           Marcos Danilo Ureña Porras
# 17     7548      795       5590                 Johnny Acosta Zamora
# 18     7548      795       5592                  Bryan Ruiz González
# 19     7548      795       5593            Christian Bolaños Navarro
# 20     7548      795       5595          Johan Alberto Venegas Ulloa
# 21     7548      795       5597                  Keylor Navas Gamboa
# 22     7548      795       5598             Óscar Esau Duarte Gaitán
# 23     7548      795       5599           David Alberto Guzmán Pérez
# 24     7548      795       5600       Francisco Javier Calvo Quesada
# 25     7548      795       5602                 Cristian Gamboa Luna
# 26     7548      795       5836                         Bryan Oviedo
# 27     7548      795       5839      Yeltsin Ignacio Tejeda Valverde
#
#               nickname  jersey_number  is_starter  starting_position_id  \
# 0          Fernandinho             17       False                     0
# 1        Gabriel Jesus              9        True                    23
# 2         Thiago Silva              2        True                     3
# 3              Willian             19        True                    17
# 4    Philippe Coutinho             11        True                    15
# 5      Roberto Firmino             20       False                     0
# 6               Neymar             10        True                    21
# 7             Casemiro              5        True                    10
# 8             Paulinho             15        True                    13
# 9              Alisson              1        True                     1
# 10                None              3        True                     5
# 11             Marcelo             12        True                     6
# 12       Douglas Costa              7       False                     0
# 13              Fágner             22        True                     2
# 14        Celso Borges              5        True                    13
# 15  Giancarlo González              3        True                     4
# 16        Marcos Ureña             21        True                    23
# 17       Johnny Acosta              2        True                     3
# 18          Bryan Ruiz             10        True                    21
# 19   Christian Bolaños              7       False                     0
# 20       Johan Venegas             11        True                    17
# 21        Keylor Navas              1        True                     1
# 22        Óscar Duarte              6        True                     5
# 23        David Guzmán             20        True                    15
# 24     Francisco Calvo             15       False                     0
# 25     Cristian Gamboa             16        True                     7
# 26                None              8        True                     8
# 27      Yeltsin Tejeda             17       False                     0
#
#        starting_position_name  minutes_played
# 0                  Substitute               6
# 1              Center Forward              93
# 2           Right Center Back              99
# 3                  Right Wing              45
# 4        Left Center Midfield              99
# 5                  Substitute              31
# 6                   Left Wing              99
# 7   Center Defensive Midfield              99
# 8       Right Center Midfield              68
# 9                  Goalkeeper              99
# 10           Left Center Back              99
# 11                  Left Back              99
# 12                 Substitute              54
# 13                 Right Back              99
# 14      Right Center Midfield              99
# 15                Center Back              99
# 16             Center Forward              54
# 17          Right Center Back              99
# 18                  Left Wing              99
# 19                 Substitute              45
# 20                 Right Wing              99
# 21                 Goalkeeper              99
# 22           Left Center Back              99
# 23       Left Center Midfield              83
# 24                 Substitute              24
# 25            Right Wing Back              75
# 26             Left Wing Back              99
# 27                 Substitute              16

# %%
df_actions = spadl.statsbomb.convert_to_actions(df_events, home_team_id=781)

# %%
df_actions = (
  spadl
  .add_names(df_actions)  # add actiontype and result names
  .merge(SBL.teams(game_id=7548), how='left')  # add team names
  .merge(SBL.players(game_id=7548), how='left')  # add player names
)

# %%
df_actions
# Out:
#       game_id                     original_event_id  period_id  time_seconds  \
# 0        7548  c6758a85-e41e-430c-85f0-8646bfc26f31          1           1.0
# 1        7548  1df25d7b-81eb-42c7-9508-5ac982da84ee          1           3.0
# 2        7548  dc30de29-8e5a-43e3-9a14-176fe177b45f          1           5.0
# 3        7548  90e2af19-d896-43dd-bbfb-ce321b77a6f2          1           8.0
# 4        7548                                   NaN          1           9.0
# ...       ...                                   ...        ...           ...
# 2193     7548  7ea9dfb9-adb5-488a-93fc-292952213f56          2        3104.0
# 2194     7548  ec84fb26-2a20-4a90-9ef3-6f8aad28781b          2        3105.0
# 2195     7548  b7728f99-998f-46c8-8ea3-0595ba54eeb2          2        3105.0
# 2196     7548  88f63c61-0a9d-431d-b67d-ea89d497e7d1          2        3176.0
# 2197     7548  4ea85ca2-64b9-449e-bce2-f864cf639924          2        3179.0
#
#       team_id  player_id     start_x    start_y       end_x      end_y  \
# 0         795     5586.0   52.058824  34.430380   87.352941  33.569620
# 1         795     5597.0   87.352941  33.569620   84.705882  38.734177
# 2         795     5597.0   84.705882  38.734177   27.352941  51.645570
# 3         781     5539.0   29.117647  49.924051   30.000000  49.924051
# 4         781     5542.0   30.000000  49.924051   30.882353  45.620253
# ...       ...        ...         ...        ...         ...        ...
# 2193      781     5837.0   92.647059  18.936709   98.823529  21.518987
# 2194      781     5837.0   98.823529  21.518987  101.470588  32.708861
# 2195      781     4320.0  100.588235  32.708861  105.000000  37.356962
# 2196      795     5595.0   52.941176  33.569620   81.176471  36.151899
# 2197      795     5597.0   81.176471  36.151899   83.823529  37.012658
#
#       type_id  result_id  bodypart_id  action_id type_name result_name  \
# 0           0          1            5          0      pass     success
# 1          21          1            0          1   dribble     success
# 2           0          0            5          2      pass        fail
# 3           0          0            0          3      pass        fail
# 4          21          1            0          4   dribble     success
# ...       ...        ...          ...        ...       ...         ...
# 2193       21          1            0       2193   dribble     success
# 2194        1          1            5       2194     cross     success
# 2195       11          1            4       2195      shot     success
# 2196        0          1            5       2196      pass     success
# 2197       21          1            0       2197   dribble     success
#
#      bodypart_name   team_name                       player_name  \
# 0       foot_right  Costa Rica        Marcos Danilo Ureña Porras
# 1             foot  Costa Rica               Keylor Navas Gamboa
# 2       foot_right  Costa Rica               Keylor Navas Gamboa
# 3             foot      Brazil          Carlos Henrique Casimiro
# 4             foot      Brazil  José Paulo Bezzera Maciel Júnior
# ...            ...         ...                               ...
# 2193          foot      Brazil            Douglas Costa de Souza
# 2194    foot_right      Brazil            Douglas Costa de Souza
# 2195     foot_left      Brazil     Neymar da Silva Santos Junior
# 2196    foot_right  Costa Rica       Johan Alberto Venegas Ulloa
# 2197          foot  Costa Rica               Keylor Navas Gamboa
#
#            nickname  jersey_number  is_starter  starting_position_id  \
# 0      Marcos Ureña             21        True                    23
# 1      Keylor Navas              1        True                     1
# 2      Keylor Navas              1        True                     1
# 3          Casemiro              5        True                    10
# 4          Paulinho             15        True                    13
# ...             ...            ...         ...                   ...
# 2193  Douglas Costa              7       False                     0
# 2194  Douglas Costa              7       False                     0
# 2195         Neymar             10        True                    21
# 2196  Johan Venegas             11        True                    17
# 2197   Keylor Navas              1        True                     1
#
#          starting_position_name  minutes_played
# 0                Center Forward              54
# 1                    Goalkeeper              99
# 2                    Goalkeeper              99
# 3     Center Defensive Midfield              99
# 4         Right Center Midfield              68
# ...                         ...             ...
# 2193                 Substitute              54
# 2194                 Substitute              54
# 2195                  Left Wing              99
# 2196                 Right Wing              99
# 2197                 Goalkeeper              99
#
# [2198 rows x 25 columns]

# %%
df_actions.groupby('type_name').size()
# Out:
# type_name
# bad_touch            26
# clearance            37
# corner_crossed        9
# corner_short          2
# cross                22
# dribble             962
# foul                 28
# freekick_crossed     12
# freekick_short       10
# goalkick              5
# interception         12
# keeper_claim          2
# keeper_punch          1
# keeper_save           7
# pass                944
# shot                 27
# tackle               37
# take_on              28
# throw_in             27
# dtype: int64

# %%
import matplotsoccer

player_id = 4320 # ネイマール
# player_id = 5539 # カゼミロ
action_type_name = 'pass'
a = df_actions[(df_actions['type_name'] == action_type_name) & (df_actions['player_id'] == player_id)]

# ref: https://github.com/TomDecroos/matplotsoccer/blob/fac4c5554d873f57a8997d735220da653bb3593b/matplotsoccer/fns.py#L285
ax = matplotsoccer.actions(
    location=a[["start_x", "start_y", "end_x", "end_y"]],
    action_type=a.type_name,
    zoom=False,
    figsize=6,
    show_legend=False
)
