# %%
from socceraction.data.statsbomb import StatsBombLoader

# %%
SBL = StatsBombLoader()

# %%
df_events = SBL.events(game_id=7548)
# Out:
# /usr/local/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
import socceraction.spadl as spadl

# %%
df_actions = spadl.statsbomb.convert_to_actions(df_events, home_team_id=781)

# %%
df_actions.shape
# Out:
# (2198, 14)

# %%
df_actions.head(20)
# Out:
#     game_id                     original_event_id  period_id  time_seconds  \
# 0      7548  c6758a85-e41e-430c-85f0-8646bfc26f31          1           1.0
# 1      7548  1df25d7b-81eb-42c7-9508-5ac982da84ee          1           3.0
# 2      7548  dc30de29-8e5a-43e3-9a14-176fe177b45f          1           5.0
# 3      7548  90e2af19-d896-43dd-bbfb-ce321b77a6f2          1           8.0
# 4      7548                                   NaN          1           9.0
# 5      7548  f14ae668-d23f-4787-a6e4-155c5e9b17e6          1          10.0
# 6      7548                                   NaN          1          11.5
# 7      7548  b7473335-db01-4ab3-a427-0f61cdc9332a          1          13.0
# 8      7548  c3aea207-ab2f-4777-9f1b-3b41bd3239a1          1          14.0
# 9      7548  26d2cd48-db02-4e51-a814-332755adbe24          1          17.0
# 10     7548  6c18b346-52e8-424f-83cc-abc4f832005f          1          22.0
# ...

# %%
df_actions = (
  spadl
  .add_names(df_actions)  # add actiontype and result names
  .merge(SBL.teams(game_id=7548))  # add team names
  .merge(SBL.players(game_id=7548))  # add player names
)
# Out:
# /usr/local/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
df_actions.shape
# Out:
# (2198, 25)

# %%
df_actions.head(10)
# Out:
#    game_id                     original_event_id  period_id  time_seconds  \
# 0     7548  c6758a85-e41e-430c-85f0-8646bfc26f31          1           1.0
# 1     7548  219fac0d-f106-4436-be6a-246f71bba0a4          1         128.0
# 2     7548  407ada69-fd95-4008-b6c9-b18c525c17e6          1         203.0
# 3     7548  cacf0452-ef70-4f55-9571-126beaf86cf7          1         204.0
# 4     7548  ef4b1ba4-164f-4a55-be2d-abb7fe2b0a2a          1         206.0
# 5     7548  277e2bbc-a00b-43d6-b649-80955ec14eb6          1         206.0
# 6     7548  17000f83-bb41-4e04-a371-fba5354f5b29          1         366.0
# 7     7548  6e65f401-b749-45d4-b0a0-94c233602c26          1         854.0
# 8     7548  2e75526d-aab8-49f7-aa78-b24cd97f5dfe          1         855.0
# 9     7548  d1829643-48eb-4290-87d8-016a2bb50f41          1         856.0
#
#    team_id  player_id    start_x    start_y      end_x      end_y  type_id  \
# 0      795     5586.0  52.058824  34.430380  87.352941  33.569620        0
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df_actions.head(10)
# Out:
#    game_id                     original_event_id  period_id  time_seconds  \
# 0     7548  c6758a85-e41e-430c-85f0-8646bfc26f31          1           1.0
# 1     7548  219fac0d-f106-4436-be6a-246f71bba0a4          1         128.0
# 2     7548  407ada69-fd95-4008-b6c9-b18c525c17e6          1         203.0
# 3     7548  cacf0452-ef70-4f55-9571-126beaf86cf7          1         204.0
# 4     7548  ef4b1ba4-164f-4a55-be2d-abb7fe2b0a2a          1         206.0
# 5     7548  277e2bbc-a00b-43d6-b649-80955ec14eb6          1         206.0
# 6     7548  17000f83-bb41-4e04-a371-fba5354f5b29          1         366.0
# 7     7548  6e65f401-b749-45d4-b0a0-94c233602c26          1         854.0
# 8     7548  2e75526d-aab8-49f7-aa78-b24cd97f5dfe          1         855.0
# 9     7548  d1829643-48eb-4290-87d8-016a2bb50f41          1         856.0
#
#    team_id  player_id    start_x    start_y      end_x      end_y  type_id  \
# 0      795     5586.0  52.058824  34.430380  87.352941  33.569620        0
# ...

# %%
# df_actions[df_actions['type_name'] == 'shot']
# print(df_actions[df_actions['type_name'] == 'shot'].shape)
# print(df_actions[df_actions['type_name'] == 'shot'])
df_actions[(df_actions['type_name'] == 'shot') & (df_actions['result_name'] == 'success')]
# Out:
#       game_id                     original_event_id  period_id  time_seconds  \
# 1807     7548  b7728f99-998f-46c8-8ea3-0595ba54eeb2          2        3105.0
# 1966     7548  9b36fcef-3875-48e8-8299-3cfc0fa1d509          2        2723.0
#
#       team_id  player_id     start_x    start_y  end_x      end_y  type_id  \
# 1807      781     4320.0  100.588235  32.708861  105.0  37.356962       11
# 1966      781     3501.0   98.823529  36.151899  105.0  35.377215       11
#
#       result_id  bodypart_id  action_id type_name result_name bodypart_name  \
# 1807          1            4       2195      shot     success     foot_left
# 1966          1            5       2052      shot     success    foot_right
#
#      team_name                    player_name           nickname  \
# 1807    Brazil  Neymar da Silva Santos Junior             Neymar
# 1966    Brazil      Philippe Coutinho Correia  Philippe Coutinho
#
# ...

# %%
import matplotsoccer

shot = 1966
a = df_actions[shot-4:shot+1].copy()

# skip "Print the game date and timestamp of the goal"

def nice_time(row):
    minute = int((row.period_id-1)*45 +row.time_seconds // 60)
    second = int(row.time_seconds % 60)
    return f"{minute}m{second}s"

a["nice_time"] = a.apply(nice_time, axis=1)
labels = a[["nice_time", "type_name", "player_name", "team_name"]]

ax = matplotsoccer.actions(
    location=a[["start_x", "start_y", "end_x", "end_y"]],
    action_type=a.type_name,
    team= a.team_name,
    result= a.result_name == "success",
    label=labels,
    labeltitle=["time", "actiontype", "player", "team"],
    zoom=False,
    figsize=6
)
