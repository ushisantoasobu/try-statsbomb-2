# %% [markdown]
# [kloppyのサイト](https://kloppy.pysport.org/open-data/)みているときに、みつけたSkillCornerというところのトラッキングデータの中身をみてみる

# %%
from kloppy import skillcorner

# %% [markdown]
# ref: https://kloppy.pysport.org/getting-started/skillcorner/

# %%
dataset = skillcorner.load(
    meta_data="../kloppy/kloppy/tests/files/skillcorner_match_data.json",
    raw_data="../kloppy/kloppy/tests/files/skillcorner_structured_data.json",
    
    # Optional arguments
    sample_rate=1/10,
#     limit=100,
    coordinates="skillcorner",
    include_empty_frames=False
)

# %%
type(dataset)
# Out:
# kloppy.domain.models.tracking.TrackingDataset

# %%
df_tracking = dataset.to_df()

# %%
df_tracking.shape
# Out:
# (3480, 1572)

# %%
print(34783/90/60)
# Out:
# 6.441296296296296

# %%
df_tracking.columns
# Out:
# Index(['period_id', 'timestamp', 'frame_id', 'ball_state',
#        'ball_owning_team_id', 'ball_x', 'ball_y', 'ball_z', 'home_22_x',
#        'home_22_y',
#        ...
#        'away_anon_11763_d', 'away_anon_11763_s', 'away_anon_11757_x',
#        'away_anon_11757_y', 'away_anon_11757_d', 'away_anon_11757_s',
#        'away_anon_11812_x', 'away_anon_11812_y', 'away_anon_11812_d',
#        'away_anon_11812_s'],
#       dtype='object', length=1572)

# %%
df_tracking.head(5)
# Out:
#    period_id  timestamp  frame_id ball_state  ball_owning_team_id     ball_x  \
# 0          1       12.0      1531       None                  NaN  18.887029
# 1          1       13.0      1541       None                  NaN  13.514701
# 2          1       14.0      1551       None                  NaN  16.835040
# 3          1       15.0      1561       None                  NaN  11.656880
# 4          1       16.0      1571       None                103.0   7.426918
#
#       ball_y    ball_z  home_22_x  home_22_y  ... away_anon_11763_d  \
# 0  30.037350  1.246213  14.195641  23.489013  ...              None
# 1  25.827027  0.657040  14.230466  15.453939  ...              None
# 2  27.427233  0.057516  15.328696  17.867260  ...              None
# 3  24.721404       NaN  13.642248  22.210971  ...              None
# 4  30.572856       NaN        NaN        NaN  ...              None
#
#   away_anon_11763_s  away_anon_11757_x  away_anon_11757_y away_anon_11757_d  \
# 0              None                NaN                NaN              None
# 1              None                NaN                NaN              None
# 2              None                NaN                NaN              None
# 3              None                NaN                NaN              None
# 4              None                NaN                NaN              None
#
#   away_anon_11757_s  away_anon_11812_x  away_anon_11812_y away_anon_11812_d  \
# 0              None                NaN                NaN              None
# 1              None                NaN                NaN              None
# 2              None                NaN                NaN              None
# 3              None                NaN                NaN              None
# 4              None                NaN                NaN              None
#
#   away_anon_11812_s
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
#
# [5 rows x 1572 columns]

# %% [markdown]
# ↑ なんで11.2秒から？？

# %%
df_tracking.tail(5)
# Out:
#       period_id  timestamp  frame_id ball_state  ball_owning_team_id  \
# 3475          2     5505.6     68035       None                103.0
# 3476          2     5506.6     68045       None                103.0
# 3477          2     5507.6     68055       None                103.0
# 3478          2     5508.6     68065       None                103.0
# 3479          2     5509.6     68075       None                103.0
#
#          ball_x     ball_y    ball_z  home_22_x  home_22_y  ...  \
# 3475  46.603345 -11.283427       NaN        NaN        NaN  ...
# 3476        NaN        NaN       NaN        NaN        NaN  ...
# 3477  47.246337  -9.883345  0.219015        NaN        NaN  ...
# 3478  44.245543 -18.881929  2.190663        NaN        NaN  ...
# 3479  39.021097 -28.307284  0.177369        NaN        NaN  ...
#
#      away_anon_11763_d away_anon_11763_s  away_anon_11757_x  \
# 3475              None              None                NaN
# 3476              None              None                NaN
# 3477              None              None                NaN
# 3478              None              None                NaN
# 3479              None              None                NaN
#
#       away_anon_11757_y away_anon_11757_d away_anon_11757_s  \
# 3475                NaN              None              None
# 3476                NaN              None              None
# 3477                NaN              None              None
# 3478                NaN              None              None
# 3479                NaN              None              None
#
#       away_anon_11812_x  away_anon_11812_y away_anon_11812_d away_anon_11812_s
# 3475                NaN                NaN              None              None
# 3476                NaN                NaN              None              None
# 3477                NaN                NaN              None              None
# 3478                NaN                NaN              None              None
# 3479                NaN                NaN              None              None
#
# [5 rows x 1572 columns]

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
# df_tracking['timestamp'].head(1000)
df_tracking['timestamp'][120:130]
# Out:
# 120    194.0
# 121    195.0
# 122    196.0
# 123    197.0
# 124    200.0
# 125    201.0
# 126    202.0
# 127    203.0
# 128    204.0
# 129    205.0
# Name: timestamp, dtype: float64

# %% [markdown]
# ↑ 一気に飛ぶときがあるな、、、ボールがアウトしているときとかはもしかして省かれている？？

# %%
df_tracking[120:130]
# Out:
#      period_id  timestamp  frame_id ball_state  ball_owning_team_id  \
# 120          1      194.0      3351       None                  NaN
# 121          1      195.0      3361       None                  NaN
# 122          1      196.0      3371       None                  NaN
# 123          1      197.0      3381       None                  NaN
# 124          1      200.0      3411       None                  NaN
# 125          1      201.0      3421       None                100.0
# 126          1      202.0      3431       None                100.0
# 127          1      203.0      3441       None                100.0
# 128          1      204.0      3451       None                100.0
# 129          1      205.0      3461       None                100.0
#
#         ball_x     ball_y    ball_z  home_22_x  home_22_y  ...  \
# 120  18.139755  14.767543 -0.009987        NaN        NaN  ...
# 121  16.797458  16.791355       NaN        NaN        NaN  ...
# 122  16.130187  17.738404       NaN        NaN        NaN  ...
# 123  16.133401  17.839304       NaN        NaN        NaN  ...
# 124  24.520052  11.330020  0.040905        NaN        NaN  ...
# 125  32.781170   4.984715       NaN        NaN        NaN  ...
# 126  29.558426  -5.313404       NaN        NaN        NaN  ...
# 127  26.711903 -13.300026       NaN        NaN        NaN  ...
# 128  25.878474 -14.813568       NaN        NaN        NaN  ...
# 129  26.285433 -13.601756       NaN        NaN        NaN  ...
#
#     away_anon_11763_d away_anon_11763_s  away_anon_11757_x  away_anon_11757_y  \
# 120              None              None                NaN                NaN
# 121              None              None                NaN                NaN
# 122              None              None                NaN                NaN
# 123              None              None                NaN                NaN
# 124              None              None                NaN                NaN
# 125              None              None                NaN                NaN
# 126              None              None                NaN                NaN
# 127              None              None                NaN                NaN
# 128              None              None                NaN                NaN
# 129              None              None                NaN                NaN
#
#     away_anon_11757_d away_anon_11757_s  away_anon_11812_x  away_anon_11812_y  \
# 120              None              None                NaN                NaN
# 121              None              None                NaN                NaN
# 122              None              None                NaN                NaN
# 123              None              None                NaN                NaN
# 124              None              None                NaN                NaN
# 125              None              None                NaN                NaN
# 126              None              None                NaN                NaN
# 127              None              None                NaN                NaN
# 128              None              None                NaN                NaN
# 129              None              None                NaN                NaN
#
#     away_anon_11812_d away_anon_11812_s
# 120              None              None
# 121              None              None
# 122              None              None
# 123              None              None
# 124              None              None
# 125              None              None
# 126              None              None
# 127              None              None
# 128              None              None
# 129              None              None
#
# [10 rows x 1572 columns]

# %%
# カラム調べる
print("\n".join(df_tracking.columns.tolist()))
# Out:
# period_id
# timestamp
# frame_id
# ball_state
# ball_owning_team_id
# ball_x
# ball_y
# ball_z
# home_22_x
# home_22_y
# home_22_d
# home_22_s
# away_23_x
# away_23_y
# away_23_d
# away_23_s
# home_5_x
# home_5_y
# home_5_d
# home_5_s
# away_28_x
# away_28_y
# away_28_d
# away_28_s
# home_18_x
# home_18_y
# home_18_d
# home_18_s
# home_25_x
# home_25_y
# home_25_d
# home_25_s
# away_33_x
# away_33_y
# away_33_d
# away_33_s
# home_8_x
# home_8_y
# home_8_d
# home_8_s
# away_10_x
# away_10_y
# away_10_d
# away_10_s
# home_27_x
# home_27_y
# home_27_d
# home_27_s
# away_19_x
# away_19_y
# away_19_d
# away_19_s
# home_19_x
# home_19_y
# home_19_d
# home_19_s
# home_32_x
# home_32_y
# home_32_d
# home_32_s
# away_7_x
# away_7_y
# away_7_d
# away_7_s
# away_15_x
# away_15_y
# away_15_d
# away_15_s
# away_5_x
# away_5_y
# away_5_d
# away_5_s
# home_29_x
# home_29_y
# home_29_d
# home_29_s
# away_14_x
# away_14_y
# away_14_d
# away_14_s
# home_9_x
# home_9_y
# home_9_d
# home_9_s
# home_anon_75_x
# home_anon_75_y
# home_anon_75_d
# home_anon_75_s
# home_1_x
# home_1_y
# home_1_d
# home_1_s
# home_anon_113_x
# home_anon_113_y
# home_anon_113_d
# home_anon_113_s
# away_anon_117_x
# away_anon_117_y
# away_anon_117_d
# away_anon_117_s
# away_16_x
# away_16_y
# away_16_d
# away_16_s
# away_1_x
# away_1_y
# away_1_d
# away_1_s
# home_anon_164_x
# home_anon_164_y
# home_anon_164_d
# home_anon_164_s
# away_anon_168_x
# away_anon_168_y
# away_anon_168_d
# away_anon_168_s
# away_anon_200_x
# away_anon_200_y
# away_anon_200_d
# away_anon_200_s
# away_anon_215_x
# away_anon_215_y
# away_anon_215_d
# away_anon_215_s
# away_anon_223_x
# away_anon_223_y
# away_anon_223_d
# away_anon_223_s
# away_anon_304_x
# away_anon_304_y
# away_anon_304_d
# away_anon_304_s
# home_anon_368_x
# home_anon_368_y
# home_anon_368_d
# home_anon_368_s
# home_anon_423_x
# home_anon_423_y
# home_anon_423_d
# home_anon_423_s
# away_anon_457_x
# away_anon_457_y
# away_anon_457_d
# away_anon_457_s
# away_anon_573_x
# away_anon_573_y
# away_anon_573_d
# away_anon_573_s
# away_anon_618_x
# away_anon_618_y
# away_anon_618_d
# away_anon_618_s
# away_anon_670_x
# away_anon_670_y
# away_anon_670_d
# away_anon_670_s
# home_anon_673_x
# home_anon_673_y
# home_anon_673_d
# home_anon_673_s
# away_anon_688_x
# away_anon_688_y
# away_anon_688_d
# away_anon_688_s
# home_anon_700_x
# home_anon_700_y
# home_anon_700_d
# home_anon_700_s
# home_anon_761_x
# home_anon_761_y
# home_anon_761_d
# home_anon_761_s
# away_anon_797_x
# away_anon_797_y
# away_anon_797_d
# away_anon_797_s
# away_anon_853_x
# away_anon_853_y
# away_anon_853_d
# away_anon_853_s
# away_anon_868_x
# away_anon_868_y
# away_anon_868_d
# away_anon_868_s
# away_anon_895_x
# away_anon_895_y
# away_anon_895_d
# away_anon_895_s
# away_anon_902_x
# away_anon_902_y
# away_anon_902_d
# away_anon_902_s
# away_anon_927_x
# away_anon_927_y
# away_anon_927_d
# away_anon_927_s
# away_anon_945_x
# away_anon_945_y
# away_anon_945_d
# away_anon_945_s
# away_anon_1003_x
# away_anon_1003_y
# away_anon_1003_d
# away_anon_1003_s
# away_anon_1021_x
# away_anon_1021_y
# away_anon_1021_d
# away_anon_1021_s
# away_anon_1047_x
# away_anon_1047_y
# away_anon_1047_d
# away_anon_1047_s
# away_anon_1056_x
# away_anon_1056_y
# away_anon_1056_d
# away_anon_1056_s
# away_anon_1127_x
# away_anon_1127_y
# away_anon_1127_d
# away_anon_1127_s
# away_anon_1136_x
# away_anon_1136_y
# away_anon_1136_d
# away_anon_1136_s
# away_anon_1182_x
# away_anon_1182_y
# away_anon_1182_d
# away_anon_1182_s
# home_anon_1216_x
# home_anon_1216_y
# home_anon_1216_d
# home_anon_1216_s
# home_anon_1217_x
# home_anon_1217_y
# home_anon_1217_d
# home_anon_1217_s
# away_anon_1321_x
# away_anon_1321_y
# away_anon_1321_d
# away_anon_1321_s
# home_anon_1350_x
# home_anon_1350_y
# home_anon_1350_d
# home_anon_1350_s
# home_anon_1354_x
# home_anon_1354_y
# home_anon_1354_d
# home_anon_1354_s
# away_anon_1367_x
# away_anon_1367_y
# away_anon_1367_d
# away_anon_1367_s
# away_anon_1379_x
# away_anon_1379_y
# away_anon_1379_d
# away_anon_1379_s
# home_anon_1400_x
# home_anon_1400_y
# home_anon_1400_d
# home_anon_1400_s
# home_anon_1438_x
# home_anon_1438_y
# home_anon_1438_d
# home_anon_1438_s
# home_anon_1439_x
# home_anon_1439_y
# home_anon_1439_d
# home_anon_1439_s
# away_anon_1444_x
# away_anon_1444_y
# away_anon_1444_d
# away_anon_1444_s
# home_anon_1470_x
# home_anon_1470_y
# home_anon_1470_d
# home_anon_1470_s
# away_anon_1558_x
# away_anon_1558_y
# away_anon_1558_d
# away_anon_1558_s
# home_anon_1579_x
# home_anon_1579_y
# home_anon_1579_d
# home_anon_1579_s
# away_anon_1572_x
# away_anon_1572_y
# away_anon_1572_d
# away_anon_1572_s
# home_anon_1578_x
# home_anon_1578_y
# home_anon_1578_d
# home_anon_1578_s
# away_anon_1582_x
# away_anon_1582_y
# away_anon_1582_d
# away_anon_1582_s
# away_anon_1580_x
# away_anon_1580_y
# away_anon_1580_d
# away_anon_1580_s
# away_anon_1588_x
# away_anon_1588_y
# away_anon_1588_d
# away_anon_1588_s
# home_anon_1625_x
# home_anon_1625_y
# home_anon_1625_d
# home_anon_1625_s
# away_anon_1627_x
# away_anon_1627_y
# away_anon_1627_d
# away_anon_1627_s
# home_anon_1634_x
# home_anon_1634_y
# home_anon_1634_d
# home_anon_1634_s
# home_anon_1641_x
# home_anon_1641_y
# home_anon_1641_d
# home_anon_1641_s
# home_anon_1663_x
# home_anon_1663_y
# home_anon_1663_d
# home_anon_1663_s
# home_anon_1675_x
# home_anon_1675_y
# home_anon_1675_d
# home_anon_1675_s
# away_anon_1701_x
# away_anon_1701_y
# away_anon_1701_d
# away_anon_1701_s
# away_anon_1810_x
# away_anon_1810_y
# away_anon_1810_d
# away_anon_1810_s
# away_anon_1842_x
# away_anon_1842_y
# away_anon_1842_d
# away_anon_1842_s
# away_anon_1881_x
# away_anon_1881_y
# away_anon_1881_d
# away_anon_1881_s
# away_anon_1930_x
# away_anon_1930_y
# away_anon_1930_d
# away_anon_1930_s
# away_anon_1954_x
# away_anon_1954_y
# away_anon_1954_d
# away_anon_1954_s
# home_anon_1975_x
# home_anon_1975_y
# home_anon_1975_d
# home_anon_1975_s
# home_anon_1983_x
# home_anon_1983_y
# home_anon_1983_d
# home_anon_1983_s
# away_anon_1981_x
# away_anon_1981_y
# away_anon_1981_d
# away_anon_1981_s
# home_anon_1994_x
# home_anon_1994_y
# home_anon_1994_d
# home_anon_1994_s
# away_anon_1990_x
# away_anon_1990_y
# away_anon_1990_d
# away_anon_1990_s
# away_anon_2004_x
# away_anon_2004_y
# away_anon_2004_d
# away_anon_2004_s
# away_anon_2015_x
# away_anon_2015_y
# away_anon_2015_d
# away_anon_2015_s
# away_anon_2020_x
# away_anon_2020_y
# away_anon_2020_d
# away_anon_2020_s
# away_anon_2032_x
# away_anon_2032_y
# away_anon_2032_d
# away_anon_2032_s
# away_anon_2060_x
# away_anon_2060_y
# away_anon_2060_d
# away_anon_2060_s
# away_anon_2127_x
# away_anon_2127_y
# away_anon_2127_d
# away_anon_2127_s
# away_anon_2184_x
# away_anon_2184_y
# away_anon_2184_d
# away_anon_2184_s
# home_anon_2187_x
# home_anon_2187_y
# home_anon_2187_d
# home_anon_2187_s
# home_anon_2192_x
# home_anon_2192_y
# home_anon_2192_d
# home_anon_2192_s
# home_anon_2239_x
# home_anon_2239_y
# home_anon_2239_d
# home_anon_2239_s
# home_anon_2335_x
# home_anon_2335_y
# home_anon_2335_d
# home_anon_2335_s
# away_anon_2371_x
# away_anon_2371_y
# away_anon_2371_d
# away_anon_2371_s
# away_anon_2397_x
# away_anon_2397_y
# away_anon_2397_d
# away_anon_2397_s
# home_anon_2400_x
# home_anon_2400_y
# home_anon_2400_d
# home_anon_2400_s
# away_anon_2480_x
# away_anon_2480_y
# away_anon_2480_d
# away_anon_2480_s
# away_anon_2474_x
# away_anon_2474_y
# away_anon_2474_d
# away_anon_2474_s
# away_anon_2511_x
# away_anon_2511_y
# away_anon_2511_d
# away_anon_2511_s
# away_anon_2554_x
# away_anon_2554_y
# away_anon_2554_d
# away_anon_2554_s
# away_anon_2578_x
# away_anon_2578_y
# away_anon_2578_d
# away_anon_2578_s
# home_anon_2610_x
# home_anon_2610_y
# home_anon_2610_d
# home_anon_2610_s
# away_anon_2694_x
# away_anon_2694_y
# away_anon_2694_d
# away_anon_2694_s
# home_anon_2829_x
# home_anon_2829_y
# away_anon_10635_s
# away_anon_10674_x
# away_anon_10674_y
# away_anon_10674_d
# away_anon_10674_s
# away_anon_10664_x
# away_anon_10664_y
# away_anon_10664_d
# away_anon_10664_s
# away_anon_10677_x
# away_anon_10677_y
# away_anon_10677_d
# away_anon_10677_s
# home_anon_10693_x
# home_anon_10693_y
# home_anon_10693_d
# home_anon_10693_s
# home_anon_10756_x
# home_anon_10756_y
# home_anon_10756_d
# home_anon_10756_s
# away_anon_10824_x
# away_anon_10824_y
# away_anon_10824_d
# away_anon_10824_s
# home_anon_10843_x
# home_anon_10843_y
# home_anon_10843_d
# home_anon_10843_s
# away_anon_10867_x
# away_anon_10867_y
# away_anon_10867_d
# away_anon_10867_s
# away_anon_10902_x
# away_anon_10902_y
# away_anon_10902_d
# away_anon_10902_s
# home_anon_11098_x
# home_anon_11098_y
# home_anon_11098_d
# home_anon_11098_s
# home_anon_11093_x
# home_anon_11093_y
# home_anon_11093_d
# home_anon_11093_s
# home_anon_11125_x
# home_anon_11125_y
# home_anon_11125_d
# home_anon_11125_s
# home_anon_11236_x
# home_anon_11236_y
# home_anon_11236_d
# home_anon_11236_s
# away_anon_11260_x
# away_anon_11260_y
# away_anon_11260_d
# away_anon_11260_s
# home_anon_11395_x
# home_anon_11395_y
# home_anon_11395_d
# home_anon_11395_s
# home_anon_11450_x
# home_anon_11450_y
# home_anon_11450_d
# home_anon_11450_s
# home_anon_11453_x
# home_anon_11453_y
# home_anon_11453_d
# home_anon_11453_s
# away_anon_11463_x
# away_anon_11463_y
# away_anon_11463_d
# away_anon_11463_s
# home_anon_11477_x
# home_anon_11477_y
# home_anon_11477_d
# home_anon_11477_s
# home_anon_11489_x
# home_anon_11489_y
# home_anon_11489_d
# home_anon_11489_s
# home_anon_11510_x
# home_anon_11510_y
# home_anon_11510_d
# home_anon_11510_s
# home_anon_11565_x
# home_anon_11565_y
# home_anon_11565_d
# home_anon_11565_s
# away_anon_11763_x
# away_anon_11763_y
# away_anon_11763_d
# away_anon_11763_s
# away_anon_11757_x
# away_anon_11757_y
# away_anon_11757_d
# away_anon_11757_s
# away_anon_11812_x
# away_anon_11812_y
# away_anon_11812_d
# away_anon_11812_s

# %%
home_list = []
for data in df_tracking.columns.tolist():
    if 'home_' in data and '_anon_' not in data:
        home_list.append(data)
print(len(home_list) / 4)
print(home_list)
# Out:
# 14.0
# ['home_22_x', 'home_22_y', 'home_22_d', 'home_22_s', 'home_5_x', 'home_5_y', 'home_5_d', 'home_5_s', 'home_18_x', 'home_18_y', 'home_18_d', 'home_18_s', 'home_25_x', 'home_25_y', 'home_25_d', 'home_25_s', 'home_8_x', 'home_8_y', 'home_8_d', 'home_8_s', 'home_27_x', 'home_27_y', 'home_27_d', 'home_27_s', 'home_19_x', 'home_19_y', 'home_19_d', 'home_19_s', 'home_32_x', 'home_32_y', 'home_32_d', 'home_32_s', 'home_29_x', 'home_29_y', 'home_29_d', 'home_29_s', 'home_9_x', 'home_9_y', 'home_9_d', 'home_9_s', 'home_1_x', 'home_1_y', 'home_1_d', 'home_1_s', 'home_10_x', 'home_10_y', 'home_10_d', 'home_10_s', 'home_6_x', 'home_6_y', 'home_6_d', 'home_6_s', 'home_14_x', 'home_14_y', 'home_14_d', 'home_14_s']

# %%
away_list = []
for data in df_tracking.columns.tolist():
    if 'away_' in data and '_anon_' not in data:
        away_list.append(data)
print(len(away_list) / 4)
print(away_list)
# Out:
# 14.0
# ['away_23_x', 'away_23_y', 'away_23_d', 'away_23_s', 'away_28_x', 'away_28_y', 'away_28_d', 'away_28_s', 'away_33_x', 'away_33_y', 'away_33_d', 'away_33_s', 'away_10_x', 'away_10_y', 'away_10_d', 'away_10_s', 'away_19_x', 'away_19_y', 'away_19_d', 'away_19_s', 'away_7_x', 'away_7_y', 'away_7_d', 'away_7_s', 'away_15_x', 'away_15_y', 'away_15_d', 'away_15_s', 'away_5_x', 'away_5_y', 'away_5_d', 'away_5_s', 'away_14_x', 'away_14_y', 'away_14_d', 'away_14_s', 'away_16_x', 'away_16_y', 'away_16_d', 'away_16_s', 'away_1_x', 'away_1_y', 'away_1_d', 'away_1_s', 'away_13_x', 'away_13_y', 'away_13_d', 'away_13_s', 'away_11_x', 'away_11_y', 'away_11_d', 'away_11_s', 'away_9_x', 'away_9_y', 'away_9_d', 'away_9_s']

# %% [markdown]
# # 特定のフレームをplotしてみる

# %%
import matplotsoccer
import matplotlib.pyplot as plt

# %%
se_first_frame = df_tracking.loc[0, :][df_tracking.loc[0, :].notna()]
se_first_frame
# Out:
# period_id            1
# timestamp         12.0
# frame_id          1531
# ball_x       18.887029
# ball_y        30.03735
# ball_z        1.246213
# home_22_x    14.195641
# home_22_y    23.489013
# away_23_x    23.531508
# away_23_y    27.161355
# home_5_x     20.955553
# home_5_y     31.434381
# away_28_x     9.364027
# away_28_y    20.832266
# home_18_x     5.804561
# home_18_y    18.471067
# home_25_x     5.296525
# home_25_y    -3.118442
# away_33_x     5.900621
# away_33_y     5.814479
# home_8_x     37.881805
# home_8_y     24.760035
# away_10_x    36.014132
# away_10_y    25.693589
# home_27_x    32.210893
# home_27_y    -6.470935
# away_19_x    23.384797
# away_19_y    18.464713
# home_19_x    19.790991
# home_19_y   -23.065539
# home_32_x    25.189245
# home_32_y    18.658417
# away_7_x     26.534644
# away_7_y      1.705975
# Name: 0, dtype: object

# %% [markdown]
# ↑
# https://github.com/SkillCorner/opendata#limitation
#
# > The data is limited to what is visible on the broadcast video. Not all the players are visible (thus included in the data) all the time. The broadcast show an average of 14 players out of 22 at each frame. During replays or close up views, the data is not included.
#
# StatsBombの360°データと同じ感じかな？？

# %%
# import re

# matplotsoccer.field("green",figsize=8, show=False)

# pattern = pattern = '(.+_\d+)_.+'

# pos_dic = {} # key = away_7, value = (28.816779, -0.094319) としたい
# for i, v in se_first_frame.items():
#     if '_x' in i:
#         matched = re.match(pattern, i) # 例: home_4 をとる
#         y = se_first_frame[matched.group(1) + "_y"]
#         plt.scatter(v, y)
        
# plt.show()

# %% [markdown]
# matplotsoccerと特に整合性ないぽい！
#
# https://kloppy.pysport.org/examples/plotting/
# みて、別の探す（あるぽい）

# %%
# !pip3 install mplsoccer

# %%
from mplsoccer.pitch import Pitch

# ref: https://mplsoccer.readthedocs.io/en/latest/gallery/pitch_setup/plot_compare_pitches.html
pitch = Pitch(pitch_color='#e7f1fa', line_zorder=1, line_color='black', pitch_length=105, pitch_width=68, pitch_type="skillcorner")
fig, ax = pitch.draw()

sc = pitch.scatter([0, 20], [0, -10], ax=ax)

# %%
# import re

# pitch = Pitch(pitch_color='#e7f1fa', line_zorder=1, line_color='black', pitch_length=105, pitch_width=68, pitch_type="skillcorner")
# fig, ax = pitch.draw()

# pattern = pattern = '(.+_\d+)_.+'

# pos_dic = {} # key = away_7, value = (28.816779, -0.094319) としたい
# for i, v in se_first_frame.items():
#     if '_x' in i:
#         matched = re.match(pattern, i) # 例: home_4 をとる
#         y = se_first_frame[matched.group(1) + "_y"]
#         plt.scatter(v, y)
#         color = "#0000FF" if 'home_' in i else "#00FF00"
#         sc = pitch.scatter(v, y, ax=ax, c=color)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 12
#      10 if '_x' in i:
#      11     matched = re.match(pattern, i) # 例: home_4 をとる
# ---> 12     y = se_first_frame[matched.group(1) + "_y"]
#      13     plt.scatter(v, y)
#      14     color = "#0000FF" if 'home_' in i else "#00FF00"
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %% [markdown]
# このフレームはボールがないからボールも描画できるようにする

# %%
ball_exists_sr = df_tracking.loc[10, :][df_tracking.loc[10, :].notna()]
ball_exists_sr

# %%
def drawFrame(sr):
    pitch = Pitch(pitch_color='#e7f1fa', line_zorder=1, line_color='black', pitch_length=105, pitch_width=68, pitch_type="skillcorner")
    fig, ax = pitch.draw(figsize=(6, 3))

    pattern = '(.+)_.+' #'(.+_\d+)_.+'

    pos_dic = {} # key = away_7, value = (28.816779, -0.094319) としたい
    for i, v in sr.items():
        if '_x' in i:
            matched = re.match(pattern, i) # 例: home_4 をとる
            y = sr[matched.group(1) + "_y"]
            color = "#FF0000" 
            if 'home_' in i:
                color = "#00FF00" 
            elif 'away_' in i:
                color = "#0000FF" 
            sc = pitch.scatter(v, y, ax=ax, c=color)

# %%
drawFrame(ball_exists_sr)

# %%
# for i in range(20):
#     sr = df_tracking.loc[i, :][df_tracking.loc[i, :].notna()]
#     drawFrame(sr)

# %% [markdown]
# matplotlibのアニメーションに挑戦！！！

# %%
import matplotlib.animation as animation

# %%
# %matplotlib notebook

# %%
fig, ax = plt.subplots()

def hoge(frame):
    ax.clear()
    
    # 毎回pitchを描画するしかない？？
    pitch = Pitch(pitch_color='#e7f1fa', line_zorder=1, line_color='black', pitch_length=105, pitch_width=68, pitch_type="skillcorner")
    pitch.draw(ax=ax)
    
    sr = df_tracking.loc[frame, :][df_tracking.loc[frame, :].notna()]
    drawFrame(sr)
    
    ###
    pattern = '(.+)_.+' #'(.+_\d+)_.+'

    pos_dic = {} # key = away_7, value = (28.816779, -0.094319) としたい
    for i, v in sr.items():
        if '_x' in i:
            matched = re.match(pattern, i) # 例: home_4 をとる
            y = sr[matched.group(1) + "_y"]
            color = "#FF0000" 
            if 'home_' in i:
                color = "#00FF00" 
            elif 'away_' in i:
                color = "#0000FF" 
            sc = pitch.scatter(v, y, ax=ax, c=color)
    ###
    
ani = animation.FuncAnimation(fig, hoge, frames=range(60), interval=1000, repeat=False)

plt.show()
